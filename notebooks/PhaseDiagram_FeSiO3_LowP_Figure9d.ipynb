# %%
import sys, os
import numpy as np

sys.path.append(os.path.join(os.path.pardir, 'python'))
from tcg_slb.phasediagram import ScipyPDReactiveODE, PDReactiveGrid, PDReactiveGridDiagnostics
from tcg_slb.base import *

# %%
pv = repr(sys.version_info.major)+'.'+repr(sys.version_info.minor)
sys.path.append(os.path.join(os.path.pardir, 'database', 'install', 'FeSiO3_all_slb_rx', 'lib', 'python'+pv, 'site-packages'))

import py_FeSiO3_all_slb_rx as tcgdb
rxn = tcgdb.FeSiO3_all_slb_rx()
rxn.report()
# Out:
# Reaction object: FeSiO3_all_slb_rx
#
# Phase 0 Fayalite_slb_ph (fa)
#      Endmember 0 Fayalite_slb_em : Fe2SiO4_(fa)
# Phase 1 Wuestite_slb_ph (wu)
#      Endmember 0 Wuestite_slb_em : FeO_(wu)
# Phase 2 Quartz_slb_ph (qtz)
#      Endmember 0 Quartz_slb_em : SiO2_(qtz)
# Phase 3 Ferrosilite_slb_ph (fs)
#      Endmember 0 Ferrosilite_slb_em : Fe2Si2O6_(fs)
# Phase 4 HPClinoferrosilite_slb_ph (hpcfs)
#      Endmember 0 HPClinoferrosilite_slb_em : Fe2Si2O6_(hpcfs)
# Phase 5 FeRingwoodite_slb_ph (feri)
#      Endmember 0 FeRingwoodite_slb_em : Fe2SiO4_(feri)
# Phase 6 Stishovite_slb_ph (st)
#      Endmember 0 Stishovite_slb_em : SiO2_(st)
#
# Reaction 0
#      Fe2SiO4_(fa) -> 2 FeO_(wu) + SiO2_(qtz)
# Reaction 1
#      0.5 Fe2SiO4_(fa) + 0.5 SiO2_(qtz) -> 0.5 Fe2Si2O6_(fs)
# Reaction 2
#      0.5 Fe2SiO4_(fa) + 0.5 SiO2_(qtz) -> 0.5 Fe2Si2O6_(hpcfs)
# Reaction 3
#      Fe2SiO4_(fa) -> Fe2SiO4_(feri)
# Reaction 4
#      SiO2_(qtz) -> SiO2_(st)
# Reaction 5
#      Fe2SiO4_(fa) -> 2 FeO_(wu) + SiO2_(st)
# Reaction 6
#      0.5 FeO_(wu) + 0.5 SiO2_(qtz) -> 0.25 Fe2Si2O6_(fs)
# Reaction 7
#      0.5 FeO_(wu) + 0.5 SiO2_(qtz) -> 0.25 Fe2Si2O6_(hpcfs)
# Reaction 8
#      0.666667 FeO_(wu) + 0.333333 SiO2_(qtz) -> 0.333333 Fe2SiO4_(feri)
# Reaction 9
#      Fe2Si2O6_(fs) -> Fe2Si2O6_(hpcfs)
# Reaction 10
#      Fe2Si2O6_(fs) -> Fe2SiO4_(feri) + SiO2_(st)
# Reaction 11
#      Fe2Si2O6_(fs) -> 2 FeO_(wu) + 2 SiO2_(st)
# Reaction 12
#      Fe2Si2O6_(hpcfs) -> Fe2SiO4_(feri) + SiO2_(st)
# Reaction 13
#      Fe2Si2O6_(hpcfs) -> 2 FeO_(wu) + 2 SiO2_(st)
# Reaction 14
#      Fe2SiO4_(feri) -> 2 FeO_(wu) + SiO2_(st)

# %% [markdown]
# ### Setup ODE

# %%
ode = ScipyPDReactiveODE(rxn)

# %% [markdown]
# #### Temperature, pressure, composition

# %%
# initial temperature, pressure and phase volume fraction
Ti = 2800.                # Kelvin
pi = GPa2Bar(0.4)         # bars
Ci0 = [0.8, 0.2]    # unused
i0 =  3                   # initial phase index

# %% [markdown]
# #### Initial conditions

# %%
mi0 = np.zeros(ode.I)
mi0[i0] = 1.
Cik0 = np.zeros(ode.K)
for i in range(ode.I):
    if ode.Kis[i] == 1:
        Cik0[sum(ode.Kis[:i]):sum(ode.Kis[:i+1])] = 1.
    else:
        Cik0[sum(ode.Kis[:i]):sum(ode.Kis[:i+1])][:] = np.asarray(Ci0)
        
display(mi0, Cik0)
# Out:
# array([0., 0., 0., 1., 0., 0., 0.])
# array([1., 1., 1., 1., 1., 1., 1.])

# %% [markdown]
# ### Solve the system of reactive ODEs at a fixed pressure and temperature

# %%
ode.solve(Ti,pi,mi0,Cik0,1000.0)

# %%
ode.stime, ode.excstr
# Out:
# (0.13312587299151346, '2')

# %%
ode.final_phases(1.e-2)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-8-fb60274666c3> in <module>
# ----> 1 ode.final_phases(1.e-2)
#
# /data/cwilson/repos/gitlab/cianwilson/tcg_slb/notebooks/../python/tcg_slb/phasediagram.py in final_phases(self, tol)
#      72
#      73     def final_phases(self,tol):
# ---> 74         assert(self.sol is not None)
#      75         phasenames = np.array([self.rxn.phases()[i].name() for i in range(self.I)], dtype=str)
#      76         phaseabbrev = np.array(['Pv' if (abbrev := self.rxn.phases()[i].abbrev()) == "MgFePv" else abbrev for i in range(self.I)], dtype=str)
#
# AssertionError:

# %% [markdown]
# ## Plotting

# %%
ode.plot()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-9-13259dfbe24a> in <module>
# ----> 1 ode.plot()
#
# /data/cwilson/repos/gitlab/cianwilson/tcg_slb/notebooks/../python/tcg_slb/phasediagram.py in plot(self)
#     429         axes = [fig.add_subplot(3,2,i+1) for i in  range(6)]
#     430
# --> 431         self.plot_axes(axes)
#     432         self.apply_labels(axes)
#     433
#
# /data/cwilson/repos/gitlab/cianwilson/tcg_slb/notebooks/../python/tcg_slb/phasediagram.py in plot_axes(self, axes, ls, label)
#     465
#     466     def plot_axes(self, axes, ls='-', label=None):
# --> 467         assert(self.sol is not None)
#     468         assert(len(axes)==6)
#     469
#
# AssertionError:

# %% [markdown]
# ## Solve for a grid

# %%
reload = True

import pickle

filename = os.path.join('output', 'scipy_bdfgrid_fesio3_lowp.pickle')

if reload:
    pfile = open(filename, 'rb')
    bdfgrid = pickle.load(pfile)
    pfile.close()
else:
    i0 = 3
    p_n = 60
    p_min = 0.0 + 0.5*29/p_n
    p_max = 29.0 - 0.5*29/p_n
    p_range = np.linspace(p_min, p_max, p_n)
    T_n = 50
    T_min =  800. + 0.5*2000/T_n
    T_max = 2800. - 0.5*2000/T_n
    T_range = np.linspace(T_min, T_max, T_n)
    end = 1e5
    bdfgrid = PDReactiveGrid()
    bdfgrid.solve(rxn, ScipyPDReactiveODE, i0, ['p', 'T'], p_range, T_range, end, **{'Cik0':Cik0})

# %%
save = True

if not reload and save:
        pfile = open(filename, 'wb')
        pickle.dump(bdfgrid, pfile)
        pfile.close()

# %%
import matplotlib.pyplot as plt

def decorate(pdrgd):
    def new_setup_axes(self,axi):
        img = plt.imread("figures/slb_figure9d.png")
        ip = axi.imshow(img)
        axi.axis('off')
        ax = axi.inset_axes([0.001,0.005,0.998,0.993])
        ax.patch.set_alpha(0.0)
        ax.set_xlim([0.0, 29.0])
        ax.set_ylim([800.0, 2800.0])
        ax.set_ylabel("Temperature (K)")
        ax.set_xlabel("Pressure (GPa)")
        return ax
    
    #replace the display with newdisplay
    pdrgd.setup_axes = new_setup_axes
    
    #return the modified student 
    return pdrgd

bdfdiag = decorate(PDReactiveGridDiagnostics)(rxn,bdfgrid)

# %%
bdfdiag.plot_rho()

# %%
# %matplotlib widget
bdfdiag.plot_phases()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [raw]
# %matplotlib inline
# bdfdiag.plot_stime()

# %% [raw]
# bdfdiag.plot_mindt()

# %% [raw]
# bdfdiag.plot_ndt()
