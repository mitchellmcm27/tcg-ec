# %%
from mcm import EcModel
reference= 'eclogitization_breakwater_monzodiorite'

# %%
phases = [
    'Clinopyroxene',
    'Orthopyroxene',
    'Quartz',
    'Feldspar', 
    'Garnet', 
    'Kyanite',
]

ems = [
    'Diopside', 'Hedenbergite', 'Clinoenstatite', 'CaTschermaks', 'Jadeite',
    'Enstatite', 'Ferrosilite', 'MgTschermaks', 'OrthoDiopside',
    'Quartz',
    'Anorthite','Albite',
    'Pyrope', 'Almandine', 'Grossular', 'MgMajorite', 'NaMajorite',
    'Kyanite'
]

# mass fractions of the phases
## Grt-Opx-Cpx granulite
## given as volume fractions
phii0 = [
    0.16, # cpx
    0.14, # opx
    0.0, # quartz
    0.57+0.05, # plag + k-spar
    0.0, # garnet
    0.08, # kyanite
 ]

xCpx =  0.229 # Fe/(Fe+Mg)
jCpx =  0.179 # Na/(Ca+Na)
xGrt =  0.588 # Fe/(Fe+Mg)
zGrt =  0.157 # Ca/(Ca+Mg+Fe[2+])
xOpx =  0.364 # Fe/(Fe+Mg)
yOpx =  0.090 # Si+Al-2 ??
NaKfs = 0.248 # Na/(Na+Ca+K)
CaKfs = 0.020 # Ca/(Ca+Na+K)
CaPl =  0.391 # Ca/(Ca+Na+K)
KPl =   0.052 # K/(K+Ca+Na)


# assume all feldspar is plag,
# assume plag is binary soln
# convert from ternary feldspar to binary

NaPl = 1 - CaPl - KPl # Na in plag with K
NaPl = NaPl/(NaPl+CaPl) # renormalize Na without K
CaPl = 1 - NaPl # renormalize Ca without K, Na + Ca = 1

Xik0 = [
    #CaMg           CaFe                       NaAl
    [(1-jCpx)*xCpx, (1-jCpx)*(1-xCpx), 0., 0., jCpx], # di, hed, *cEn, *cats, jd

    #Mg      Fe
    [1-xOpx, xOpx, 0., 0.], # en, fs, *mgts, *oDi

    [1.], # quartz

    #Ca,   Na
    [CaPl, NaPl], # an, ab
    
    #Mg3,               Fe3,           Ca3
    [(1-zGrt)*(1-xGrt), (1-zGrt)*xGrt, zGrt, 0., 0.], # py, alm, gr, *mgmaj, *namaj

    [1.], # kyanite
]

# %%
model = EcModel(
    reference,
    "eclogitization_agu3_slb_rx",
    phii0=phii0,
    Xik0=Xik0,
    P0=1.95,
    T0=850.+273.15
)

model.run(reload=False,save=True,end_t=1e4)
# Out:
#                 Clinopyroxene_slb_ph  Orthopyroxene_slb_ph  Quartz_slb_ph  \
# Mode (initial)              0.188012          1.631077e-01       0.000000
# Mode (final)                0.526342         -2.977001e-13       0.123195
#
#                 Feldspar_slb_ph  Garnet_slb_ph  Kyanite_slb_ph
# Mode (initial)     5.514036e-01       0.000000        0.097477
# Mode (final)      -7.404727e-14       0.252986        0.097477
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /workspaces/tcg-ec/systems/ec/notebooks/eclogitizaiton_breakwater_monzodiorite.ipynb Cell 3 in <cell line: 10>()
#       <a href='vscode-notebook-cell://dev-container%...-ec/systems/ec/notebooks/eclogitizaiton_breakwater_monzodiorite.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> model = EcModel(
#       <a href='vscode-notebook-cell://dev-container%...-ec/systems/ec/notebooks/eclogitizaiton_breakwater_monzodiorite.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a>     reference,
#       <a href='vscode-notebook-cell://dev-container%...-ec/systems/ec/notebooks/eclogitizaiton_breakwater_monzodiorite.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a>     "eclogitization_agu3_slb_rx",
#    (...)
#       <a href='vscode-notebook-cell://dev-container%...-ec/systems/ec/notebooks/eclogitizaiton_breakwater_monzodiorite.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a>     T0=850.+273.15
#       <a href='vscode-notebook-cell://dev-container%...-ec/systems/ec/notebooks/eclogitizaiton_breakwater_monzodiorite.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a> )
# ---> <a href='vscode-notebook-cell://dev-container%...-ec/systems/ec/notebooks/eclogitizaiton_breakwater_monzodiorite.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a> model.run(reload=False,save=True,end_t=1e4)
#
# File /workspaces/tcg-ec/systems/ec/notebooks/mcm.py:85, in EcModel.run(self, end_t, reload, save, plot, **kwargs)
#      83     pass
#      84 if self.T is not None and self.P is not None:
# ---> 85     grid = self.solve_reaction_grid(
#      86         reload=reload, save=save, end_t=end_t, **kwargs)
#      87     self.grid = grid
#      88     if(plot):
#
# File /workspaces/tcg-ec/systems/ec/notebooks/mcm.py:167, in EcModel.solve_reaction_grid(self, end_t, reload, save, odeClass, Da)
#     163 i0 = 2  # doesn't matter as long as you pass cik0
#     165 bdfgrid = PDReactiveGrid()
# --> 167 bdfgrid.solve(self.rxn, ScipyPDReactiveODE, i0, [
#     168               'T', 'p'], self.T, self.P, end_t, Cik0=self.Cik0, mi0=self.mi0)
#     170 if save:
#     171     self.save_grid(bdfgrid)
#
# File /workspaces/tcg-ec/systems/ec/notebooks/../python/tcg_slb/phasediagram/base.py:633, in PDReactiveGrid.solve(self, rxn, odecls, i0, ax_args, x_range, y_range, end, **kwargs)
#     629     mi0[self.i0] = 1.0
#     632 # solve the ODE at the specific p, T, etc.
# --> 633 ode.solve(T,GPa2Bar(p),mi0,Cik0,end,Da=_Da,**kwargs)
#     635 # populate the grid cell with the inputs
#     636 self.Tgrid[i][j]    = T
#
# File /workspaces/tcg-ec/systems/ec/notebooks/../python/tcg_slb/phasediagram/scipy.py:29, in ScipyPDReactiveODE.solve(self, T, p, mi0, Cik0, end, **kwargs)
#      27 #with redirect_stdout(so), redirect_stderr(se):
#      28 tic = time.perf_counter()
# ---> 29 sol = solve_ivp(self.rhs, [0,end], u0, dense_output=True, method=method, rtol=rtol, atol=atol, jac=self.jac)
#      30 self.sol = sol
#      31 toc = time.perf_counter()
#
# File /usr/local/lib/python3.8/dist-packages/scipy/integrate/_ivp/ivp.py:576, in solve_ivp(fun, t_span, y0, method, t_eval, dense_output, events, vectorized, args, **options)
#     574 status = None
#     575 while status is None:
# --> 576     message = solver.step()
#     578     if solver.status == 'finished':
#     579         status = 0
#
# File /usr/local/lib/python3.8/dist-packages/scipy/integrate/_ivp/base.py:181, in OdeSolver.step(self)
#     179 else:
#     180     t = self.t
# --> 181     success, message = self._step_impl()
#     183     if not success:
#     184         self.status = 'failed'
#
# File /usr/local/lib/python3.8/dist-packages/scipy/integrate/_ivp/bdf.py:360, in BDF._step_impl(self)
#     358 if current_jac:
#     359     break
# --> 360 J = self.jac(t_new, y_predict)
#     361 LU = None
#     362 current_jac = True
#
# File /usr/local/lib/python3.8/dist-packages/scipy/integrate/_ivp/bdf.py:276, in BDF._validate_jac.<locals>.jac_wrapped(t, y)
#     274 def jac_wrapped(t, y):
#     275     self.njev += 1
# --> 276     return np.asarray(jac(t, y), dtype=y0.dtype)
#
# File /workspaces/tcg-ec/systems/ec/notebooks/../python/tcg_slb/phasediagram/base.py:404, in BasePDReactiveODE.jac(self, t, u)
#     402 Gammaik = self.Gammaik(T,p,Cs,mi)
#     403 dGammaidus = self.dGammaidus(T,p,Cs,mi)
# --> 404 dGammaikdus = self.dGammaikdus(T,p,Cs,mi)
#     406 dudu = np.zeros((self.I+self.K,self.I+self.K))
#     407 sKi = 0
#
# File /workspaces/tcg-ec/systems/ec/notebooks/../python/tcg_slb/phasediagram/base.py:326, in BasePDReactiveODE.dGammaikdus(self, T, p, Cs, mi)
#     324 for di in range(self.I):
#     325     for dk in range(self.Kis[di]):
# --> 326         dGammaikdCikik = self.rxn.dGamma_ik_dC(T,p,Cs,mi,i,k,di,dk)
#     327         dGammaikdus[sKi+k,sKi2+dk] = dGammaikdCikik
#     328     sKi2 += self.Kis[di]
#
# KeyboardInterrupt:

# %%
# Out:
# Reaction object: eclogitization_agu2_slb_rx
#
# Phase 0 Clinopyroxene_slb_ph (cpx)
#      Endmember 0 Diopside_slb_em : CaMgSi2O6_(cpx)
#      Endmember 1 Hedenbergite_slb_em : CaFeSi2O6_(cpx)
#      Endmember 2 Clinoenstatite_slb_em : Mg2Si2O6_(cpx)
#      Endmember 3 CaTschermaks_slb_em : CaAl2SiO6_(cpx)
#      Endmember 4 Jadeite_slb_em : NaAlSi2O6_(cpx)
# Phase 1 Orthopyroxene_slb_ph (opx)
#      Endmember 0 Enstatite_slb_em : Mg2Si2O6_(opx)
#      Endmember 1 Ferrosilite_slb_em : Fe2Si2O6_(opx)
#      Endmember 2 MgTschermaks_slb_em : MgAl2SiO6_(opx)
#      Endmember 3 OrthoDiopside_slb_em : CaMgSi2O6_(opx)
# Phase 2 Quartz_slb_ph (qtz)
#      Endmember 0 Quartz_slb_em : SiO2_(qtz)
# Phase 3 Feldspar_slb_ph (plg)
#      Endmember 0 Anorthite_slb_em : CaAl2Si2O8_(plg)
#      Endmember 1 Albite_slb_em : NaAlSi3O8_(plg)
# Phase 4 Garnet_slb_ph (gt)
#      Endmember 0 Pyrope_slb_em : Mg3Al2Si3O12_(gt)
#      Endmember 1 Almandine_slb_em : Fe3Al2Si3O12_(gt)
#      Endmember 2 Grossular_slb_em : Ca3Al2Si3O12_(gt)
#      Endmember 3 MgMajorite_slb_em : Mg4Si4O12_(gt)
#      Endmember 4 NaMajorite_slb_em : Na2Al2Si4O12_(gt)
# Phase 5 Kyanite_slb_ph (ky)
#      Endmember 0 Kyanite_slb_em : Al2SiO5_(ky)
#
# Reaction 0
#      CaAl2Si2O8_(plg) -> CaAl2SiO6_(cpx) + SiO2_(qtz)
# Reaction 1
#      0.5 Mg2Si2O6_(opx) + 0.5 CaAl2Si2O8_(plg) -> 0.5 CaMgSi2O6_(cpx) + 0.5 MgAl2SiO6_(opx) + 0.5 SiO2_(qtz)
# Reaction 2
#      0.666667 Mg2Si2O6_(opx) + 0.333333 CaAl2Si2O8_(plg) -> 0.333333 CaMgSi2O6_(cpx) + 0.333333 SiO2_(qtz) + 0.333333 Mg3Al2Si3O12_(gt)
# Reaction 3
#      0.5 Mg2Si2O6_(opx) + 0.5 CaAl2Si2O8_(plg) -> 0.5 SiO2_(qtz) + 0.333333 Mg3Al2Si3O12_(gt) + 0.166667 Ca3Al2Si3O12_(gt)
# Reaction 4
#      0.666667 Fe2Si2O6_(opx) + 0.333333 CaAl2Si2O8_(plg) -> 0.333333 CaFeSi2O6_(cpx) + 0.333333 SiO2_(qtz) + 0.333333 Fe3Al2Si3O12_(gt)
# Reaction 5
#      0.5 Fe2Si2O6_(opx) + 0.5 CaAl2Si2O8_(plg) -> 0.5 SiO2_(qtz) + 0.333333 Fe3Al2Si3O12_(gt) + 0.166667 Ca3Al2Si3O12_(gt)
# Reaction 6
#      0.5 Mg2Si2O6_(opx) + 0.5 MgAl2SiO6_(opx) -> 0.5 Mg3Al2Si3O12_(gt)
# Reaction 7
#      0.5 CaAl2SiO6_(cpx) + 0.5 Mg2Si2O6_(opx) -> 0.333333 Mg3Al2Si3O12_(gt) + 0.166667 Ca3Al2Si3O12_(gt)
# Reaction 8
#      0.5 Fe2Si2O6_(opx) + 0.5 MgAl2SiO6_(opx) -> 0.166667 Mg3Al2Si3O12_(gt) + 0.333333 Fe3Al2Si3O12_(gt)
# Reaction 9
#      0.5 CaAl2SiO6_(cpx) + 0.5 Fe2Si2O6_(opx) -> 0.333333 Fe3Al2Si3O12_(gt) + 0.166667 Ca3Al2Si3O12_(gt)
# Reaction 10
#      NaAlSi3O8_(plg) -> NaAlSi2O6_(cpx) + SiO2_(qtz)
# Reaction 11
#      0.75 CaAl2Si2O8_(plg) + 0.25 Mg3Al2Si3O12_(gt) -> 0.75 MgAl2SiO6_(opx) + 0.75 SiO2_(qtz) + 0.25 Ca3Al2Si3O12_(gt)
# Reaction 12
#      0.5 CaMgSi2O6_(cpx) + 0.5 CaAl2Si2O8_(plg) -> 0.5 SiO2_(qtz) + 0.166667 Mg3Al2Si3O12_(gt) + 0.333333 Ca3Al2Si3O12_(gt)
# Reaction 13
#      0.5 CaFeSi2O6_(cpx) + 0.5 CaAl2Si2O8_(plg) -> 0.5 SiO2_(qtz) + 0.166667 Fe3Al2Si3O12_(gt) + 0.333333 Ca3Al2Si3O12_(gt)
# Reaction 14
#      0.5 CaAl2SiO6_(cpx) + 0.5 SiO2_(qtz) -> 0.5 CaAl2Si2O8_(plg)
